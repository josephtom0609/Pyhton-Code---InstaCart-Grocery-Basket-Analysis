# %%
# Importing Libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Import Merged Orders/Products dataset from Prepared Data

# %%
path=r'C:\Users\LENOVO\Desktop\CF - Data Analytics\Achievement 5\Achievement 5 - PROJECT'

# Assigning location of dataset to a variable

# %%
df_ords_prods_MERGED=pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# Importing merged pickle file of Orders and Products

# %%
df_ords_prods_MERGED.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32404859 entries, 0 to 32404858
# Data columns (total 14 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int32
#  1   user_id                 int32
#  2   order_number            int16
#  3   orders_day_of_week      int8
#  4   ordered_hour            int8
#  5   days_since_prior_order  float16
#  6   product_id              int8
#  7   add_to_cart_order       int8
#  8   reordered               int8
#  9   Unnamed: 0              int8
#  10  product_name            object
#  11  aisle_id                int8
#  12  department_id           int8
#  13  prices                  float64
# dtypes: float16(1), float64(1), int16(1), int32(2), int8(8), object(1)
# memory usage: 1.3+ GB

# %%
#df_ords_prods_MERGED['order_id'] = df_ords_prods_MERGED['order_id'].astype('int32')

#df_ords_prods_MERGED['user_id'] = df_ords_prods_MERGED['user_id'].astype('int32')

#df_ords_prods_MERGED['order_number'] = df_ords_prods_MERGED['order_number'].astype('int16')

#df_ords_prods_MERGED['orders_day_of_week'] = df_ords_prods_MERGED['orders_day_of_week'].astype('int8')

#df_ords_prods_MERGED['ordered_hour'] = df_ords_prods_MERGED['ordered_hour'].astype('int8')

#df_ords_prods_MERGED['days_since_prior_order'] = df_ords_prods_MERGED['days_since_prior_order'].astype('float16')

#df_ords_prods_MERGED['product_id'] = df_ords_prods_MERGED['product_id'].astype('int8')

#df_ords_prods_MERGED['add_to_cart_order'] = df_ords_prods_MERGED['add_to_cart_order'].astype('int8')

#df_ords_prods_MERGED['reordered'] = df_ords_prods_MERGED['reordered'].astype('int8')

#df_ords_prods_MERGED['aisle_id'] = df_ords_prods_MERGED['aisle_id'].astype('int8')

#df_ords_prods_MERGED['department_id'] = df_ords_prods_MERGED['department_id'].astype('int8')

df_ords_prods_MERGED['Unnamed: 0'] = df_ords_prods_MERGED['Unnamed: 0'].astype('int8')


# Coverting datatypes of all variables to a lower datatype

# %% [markdown]
# # Creating a subset of million rows from Orders/Products dataset

# %%
df_ords_prods_MERGED.shape
# Out:
# (32404859, 14)

# %%
df_1=df_ords_prods_MERGED[:1000000]

# Creating subset of merged dataset to contain only 1,000,000 rows

# %%
df_1.shape
# Out:
# (1000000, 14)

# %% [markdown]
# # IF Statements with USER DEFINED FUNCTION

# %%
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'
    
# Creating a function to categorize products based on their prices

# %%
df_1['price_range']=df_1.apply(price_label, axis=1)

# Applying the function on the subset dataframe df_1 having 1,000,000 rows
# Out:
# <ipython-input-40-b730ee710f74>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1['price_range']=df_1.apply(price_label, axis=1)

# %%
df_1['price_range'].value_counts(dropna=False)

# Checking frequency of different price ranges
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
df_1['prices'].max()
# Out:
# 14.8

# %%
df_1.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  ordered_hour  \
# 0   2539329        1             1                   2             8
# 1   2398795        1             2                   3             7
# 2    473747        1             3                   3            12
# 3   2254736        1             4                   4             7
# 4    431534        1             5                   4            15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     0.0         -60                  1          0
# 1                    15.0         -60                  1          1
# 2                    21.0         -60                  1          1
# 3                    29.0         -60                  1          1
# 4                    28.0         -60                  1          1
#
#    Unnamed: 0 product_name  aisle_id  department_id  prices        price_range
# ...

# %% [markdown]
# # IF Statements with LOC() FUNCTION on Orders/Products subset

# %%
df_1.loc[df_1['prices'] > 15, 'price_range_loc'] = 'High-range product'

# Setting up conditions for Prices greater than 15
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\pandas\core\indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\LENOVO\anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
df_1.loc[(df_1['prices'] <= 15) & (df_1['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# Setting up conditions for Prices between 5 and 15
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
df_1.loc[df_1['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# Setting up conditions for Prices less than or equal to 5
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\pandas\core\indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
df_1['price_range_loc'].value_counts(dropna=False)

# checking count of different products by price range
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range_loc, dtype: int64

# %%
df_1.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  ordered_hour  \
# 0   2539329        1             1                   2             8
# 1   2398795        1             2                   3             7
# 2    473747        1             3                   3            12
# 3   2254736        1             4                   4             7
# 4    431534        1             5                   4            15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     0.0         -60                  1          0
# 1                    15.0         -60                  1          1
# 2                    21.0         -60                  1          1
# 3                    29.0         -60                  1          1
# 4                    28.0         -60                  1          1
#
#    Unnamed: 0 product_name  aisle_id  department_id  prices  \
# 0         -61         Soda        77              7     9.0
# ...

# %% [markdown]
# # IF Statements with LOC() FUNCTION on Merged Orders/Products dataset

# %%
df_ords_prods_MERGED.tail()

#checking last 5 rows of the dataframe
# Out:
#           order_id  user_id  order_number  orders_day_of_week  ordered_hour  \
# 32404854   1320836   202557            17                   2            15
# 32404855     31526   202557            18                   5            11
# 32404856    758936   203436             1                   2             7
# 32404857   2745165   203436             2                   3             5
# 32404858   3093936   205420             1                   4            14
#
#           days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 32404854                     1.0          33                  2          1
# 32404855                     3.0          33                  2          1
# 32404856                     0.0          98                  4          0
# 32404857                    15.0          98                 16          1
# 32404858                     0.0        -110                  8          0
#
# ...

# %%
df_ords_prods_MERGED.dtypes

# Checking the datatypes of the variables in the dataframe
# Out:
# order_id                    int32
# user_id                     int32
# order_number                int16
# orders_day_of_week           int8
# ordered_hour                 int8
# days_since_prior_order    float16
# product_id                   int8
# add_to_cart_order            int8
# reordered                    int8
# Unnamed: 0                   int8
# product_name               object
# aisle_id                     int8
# department_id                int8
# prices                    float64
# price_range_loc            object
# Busiest Day                object
# Busiest DAYS               object
# dtype: object

# %%
df_ords_prods_MERGED.loc[df_ords_prods_MERGED['prices'] > 15, 'price_range_loc'] = 'High-range Product'

# Applying condition on 'prices' column use loc() function

# %%
df_ords_prods_MERGED.loc[(df_ords_prods_MERGED['prices'] <= 15) & (df_ords_prods_MERGED['prices'] > 5), 'price_range_loc'] = 'Mid-range Product'

# Applying condition on 'prices' column use loc() function

# %%
df_ords_prods_MERGED.loc[df_ords_prods_MERGED['prices'] <=5, 'price_range_loc'] = 'Low-range Product'

# Applying condition on 'prices' column use loc() function

# %%
df_ords_prods_MERGED.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  ordered_hour  \
# 0   2539329        1             1                   2             8
# 1   2398795        1             2                   3             7
# 2    473747        1             3                   3            12
# 3   2254736        1             4                   4             7
# 4    431534        1             5                   4            15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     0.0         -60                  1          0
# 1                    15.0         -60                  1          1
# 2                    21.0         -60                  1          1
# 3                    29.0         -60                  1          1
# 4                    28.0         -60                  1          1
#
#    Unnamed: 0 product_name  aisle_id  department_id  prices  \
# 0         -61         Soda        77              7     9.0
# ...

# %% [markdown]
# # IF Statements with FOR Loops

# %%
# To check how many ordes happen on each day

df_ords_prods_MERGED['orders_day_of_week'].value_counts(dropna=False)

# Value 0 = Sunday
# Value 6 = Saturday
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_week, dtype: int64

# %%
result = []

for value in df_ords_prods_MERGED["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")
    
    # For Loop with if statememts to check the busiest, least regularly busy days in a week

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
df_ords_prods_MERGED['Busiest Day'] = result

# Assigning values in 'result' to a new column 'Busiest Day'

# %%
df_ords_prods_MERGED['Busiest Day'].value_counts(dropna=False)
# Out:
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: Busiest Day, dtype: int64

# %%
df_ords_prods_MERGED['Busiest Day'] = df_ords_prods_MERGED['Busiest Day'].astype('str')

# Converting new column 'Busiest Day' datatype to string

# %% [markdown]
# # ----- EXERCISE 5.7 - DERIVING NEW VARIABLES ----

# %% [markdown]
# ## TASK 1

# %%
df_ords_prods_MERGED.head()

# Displaying the merged orders products dataframe with 2 new columns - 'price_range_loc' and  'Busiest Day'
# Out:
#    order_id  user_id  order_number  orders_day_of_week  ordered_hour  \
# 0   2539329        1             1                   2             8
# 1   2398795        1             2                   3             7
# 2    473747        1             3                   3            12
# 3   2254736        1             4                   4             7
# 4    431534        1             5                   4            15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     0.0         -60                  1          0
# 1                    15.0         -60                  1          1
# 2                    21.0         -60                  1          1
# 3                    29.0         -60                  1          1
# 4                    28.0         -60                  1          1
#
#    Unnamed: 0 product_name  aisle_id  department_id  prices  \
# 0         -61         Soda        77              7     9.0
# ...

# %% [markdown]
# ## TASK 2

# %%
df_ords_prods_MERGED['orders_day_of_week'].value_counts(dropna=False)

# checking the frequency of each days of the week
# 0 = Sunday
# 1 = Monday
# 3 = Wednesday
# 4 = Thursday
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_week, dtype: int64

# %%
result_1 = []

for x in df_ords_prods_MERGED["orders_day_of_week"]:
    if ((x == 0) or (x == 1)):
        result_1.append("Busy Days")
    elif ((x == 3) or (x == 4)):
        result_1.append("Slow Days")
    else:
        result_1.append("Regular Days")`
    

# For Loop with if statememts to check the busiest and slowest days in a week

# %%
result_1

# printing data in 'result' variable
# Out:
# ['Regular Days',
#  'Slow Days',
#  'Slow Days',
#  'Slow Days',
#  'Slow Days',
#  'Regular Days',
#  'Busy Days',
#  'Busy Days',
#  'Busy Days',
#  'Slow Days',
#  'Busy Days',
#  'Regular Days',
#  'Regular Days',
#  'Busy Days',
#  'Busy Days',
#  'Regular Days',
#  'Regular Days',
#  'Slow Days',
#  'Slow Days',
#  'Slow Days',
#  'Slow Days',
#  'Slow Days',
#  'Slow Days',
#  'Busy Days',
#  'Busy Days',
#  'Busy Days',
#  'Regular Days',
#  'Regular Days',
#  'Busy Days',
#  'Regular Days',
#  'Regular Days',
#  'Busy Days',
#  'Regular Days',
#  'Regular Days',
#  'Regular Days',
#  'Slow Days',
#  'Regular Days',
#  'Slow Days',
#  'Busy Days',
#  'Busy Days',
#  'Regular Days',
#  'Slow Days',
#  'Slow Days',
#  'Regular Days',
#  'Regular Days',
#  'Busy Days',
#  'Busy Days',
#  'Regular Days',
#  'Busy Days',
#  'Busy Days',
#  'Slow Days',
#  'Regular Days',
#  'Busy Days',
#  'Busy Days',
#  'Busy Days',
#  'Busy Days',
#  'Busy Days',
#  'Regular Days',
# ...

# %%
df_ords_prods_MERGED['Busiest DAYS']=result_1

# Assigning values in 'result_1' to a new column 'Busiest DAYS'

# %%
df_ords_prods_MERGED.tail()
# Out:
#           order_id  user_id  order_number  orders_day_of_week  ordered_hour  \
# 32404854   1320836   202557            17                   2            15
# 32404855     31526   202557            18                   5            11
# 32404856    758936   203436             1                   2             7
# 32404857   2745165   203436             2                   3             5
# 32404858   3093936   205420             1                   4            14
#
#           days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 32404854                     1.0          33                  2          1
# 32404855                     3.0          33                  2          1
# 32404856                     0.0          98                  4          0
# 32404857                    15.0          98                 16          1
# 32404858                     0.0        -110                  8          0
#
# ...

# %% [markdown]
# ## TASK 3

# %%
df_ords_prods_MERGED['Busiest DAYS'].value_counts(dropna=False)

# Checking the frequency of 'Busy Days' and 'Slow Days' for accuracy purposes

# As per earlier check frequency of day 0 = 6204182 and day 1 = 5660230 , which adds upto 11864412 Busy Days
# Out:
# Regular Days    12916111
# Busy Days       11864412
# Slow Days        7624336
# Name: Busiest DAYS, dtype: int64

# %% [markdown]
# ## TASK 4

# %%
df_ords_prods_MERGED['ordered_hour'].value_counts(dropna=False)

# Checking the frequency for the column 'ordered_hour'
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: ordered_hour, dtype: int64

# %%
df_ords_prods_MERGED.loc[df_ords_prods_MERGED['ordered_hour'].isin([9, 10, 11, 12, 13, 14, 15, 16]), 'Busiest_Period_of_Day'] = 'Most Orders'

# condition to check for time period with most orders and enter result in column 'Busiest Period of Day'

# %%
df_ords_prods_MERGED.loc[df_ords_prods_MERGED['ordered_hour'].isin([7, 8, 17, 18, 19, 20, 21, 22]), 'Busiest_Period_of_Day'] = 'Average Orders'

# condition to check for time period with average orders and enter result in column 'Busiest Period of Day'

# %%
df_ords_prods_MERGED.loc[df_ords_prods_MERGED['ordered_hour'].isin([0, 1, 2, 3, 4, 5, 6, 23]), 'Busiest_Period_of_Day'] = 'Fewest Orders'

# condition to check for time period with few orders and enter result in column 'Busiest Period of Day'

# %% [markdown]
# ## TASK 5

# %%
df_ords_prods_MERGED['Busiest_Period_of_Day'].value_counts(dropna=False)

# Displaying frequency of the new column 'Busiest_Period_of_Day'
# Out:
# Most Orders       21118071
# Average Orders     9997651
# Fewest Orders      1289137
# Name: Busiest_Period_of_Day, dtype: int64

# %% [markdown]
# ## TASK 7

# %%
df_ords_prods_export=df_ords_prods_MERGED.drop(columns=['Unnamed: 0'])

# Dropping column 'Unnamed: 0' and assigning datatset to a new dataframe

# %%
df_ords_prods_export.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_new_columns.pkl'))

# Exporting orders and products dataset with new columns in pickle format
